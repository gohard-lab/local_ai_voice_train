# %% [markdown]
# <a href="https://colab.research.google.com/github/gohard-lab/local_ai_voice_train/blob/main/local_ai_voice_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 나의 레포지토리를 코랩 가상 컴퓨터로 복제
# !git clone https://github.com/gohard-lab/local_ai_voice_train.git
# 2. 작업 디렉토리를 복제된 폴더 안으로 이동
# %cd local_ai_voice_train
# Out:
# Cloning into 'local_ai_voice_train'...
# remote: Enumerating objects: 166, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 166 (delta 7), reused 10 (delta 4), pack-reused 151 (from 2)
# Receiving objects: 100% (166/166), 68.76 MiB | 5.54 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/local_ai_voice_train

# %%
# 코랩 환경에 uv를 설치하고 pyproject.toml에 정의된 패키지를 동기화
# !pip install uv
# !uv pip install --system .
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.0/25.0 MB 44.5 MB/s eta 0:00:00
# ...
# Using Python 3.12.13 environment at: /usr
# Resolved 97 packages in 889ms
# Prepared 32 packages in 1m 10s
# Uninstalled 2 packages in 996ms
# Installed 32 packages in 430ms
#  + cuda-bindings==13.3.1
#  + cuda-pathfinder==1.5.5
#  + cuda-toolkit==13.0.2
#  + local-ai-voice-train==0.1.0 (from file:///content/local_ai_voice_train)
#  + nvidia-cublas==13.1.1.3
#  + nvidia-cuda-cupti==13.0.85
#  + nvidia-cuda-nvrtc==13.0.88
#  + nvidia-cuda-runtime==13.0.96
#  + nvidia-cudnn-cu13==9.20.0.48
#  + nvidia-cufft==12.0.0.61
#  + nvidia-cufile==1.15.1.6
#  + nvidia-curand==10.4.0.35
#  + nvidia-cusolver==12.0.4.66
#  + nvidia-cusparse==12.6.3.3
#  + nvidia-cusparselt-cu13==0.8.1
#  + nvidia-nccl-cu13==2.29.7
#  + nvidia-nvjitlink==13.0.88
#  + nvidia-nvshmem-cu13==3.4.5
#  + nvidia-nvtx==13.0.85
#  + postgrest==2.31.0
#  + pydeck==0.9.2
#  + realtime==2.31.0
#  - requests==2.32.4
#  + requests==2.34.2
# ...

# %%
# 시청자가 준비한 원본 wav 파일을 넣고 전처리기를 돌리는 명령
# !python src/local_ai_voice_trainer.py
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# 2026-06-11 07:15:04.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# [INFO] Accessing source file: dataset/raw_source/The_Residence.m4a
# 2026-06-11 07:15:04.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# clipchamp_slices 폴더 안의 모든 파일(.wav 등)을 한 번에 강제 삭제합니다.
# 1. 코랩의 최상위 루트(content) 경로로 완전히 빠져나옵니다.
# %cd /content

# 2. 거기서부터 절대 경로를 지정해 찌꺼기 파일들을 통째로 강제 삭제합니다.
# !rm -rf /content/local_ai_voice_train/dataset/clipchamp_slices/*
# Out:
# /content
